# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# # 1- Data Collecting

# %%
df=pd.read_csv("my_paypal_creditcard.csv")

# %% [markdown]
# # 2- Data Exploration

# %%
df.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
# ...

# %%
#Statitical description of our data set
df.describe()
# Out:
#                 Time            V1            V2            V3            V4  \
# count  284807.000000  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean    94813.859575  1.168375e-15  3.416908e-16 -1.379537e-15  2.074095e-15
# std     47488.145955  1.958696e+00  1.651309e+00  1.516255e+00  1.415869e+00
# min         0.000000 -5.640751e+01 -7.271573e+01 -4.832559e+01 -5.683171e+00
# 25%     54201.500000 -9.203734e-01 -5.985499e-01 -8.903648e-01 -8.486401e-01
# 50%     84692.000000  1.810880e-02  6.548556e-02  1.798463e-01 -1.984653e-02
# 75%    139320.500000  1.315642e+00  8.037239e-01  1.027196e+00  7.433413e-01
# max    172792.000000  2.454930e+00  2.205773e+01  9.382558e+00  1.687534e+01
#
#                  V5            V6            V7            V8            V9  \
# count  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean   9.604066e-16  1.487313e-15 -5.556467e-16  1.213481e-16 -2.406331e-15
# ...

# %%
np.unique(df["Class"],return_counts=True)
# Out:
# (array([0, 1], dtype=int64), array([284315,    492], dtype=int64))

# %%
#Checking the distribution of the Class according to the Amount of transaction associated
target_var="Class"
dependant_var="Amount"
operation_list={
    "Count":"count",
    "Min":"min",
    "Max":"max",
    "Sum":"sum",
    
}

def groupby_info_target_var(df,target_var,dependant_var,operations):
    groupby_tab={"Class":[0,1]}
    for operation_name, operation in operations.items():
        res=df.groupby([target_var])[dependant_var].agg(operation)
        groupby_tab[f"{operation_name}"]=[res[0],res[1]]
    groupby_tab=pd.DataFrame(groupby_tab)
    return groupby_tab

groupby_tab=groupby_info_target_var(df,target_var,dependant_var,operation_list)

groupby_tab
# Out:
#    Class   Count  Min       Max          Sum
# 0      0  284315  0.0  25691.16  25102462.04
# 1      1     492  0.0   2125.87     60127.97

# %%
""" 1- By analysing the above table, we noticed the number of fraudulent transaction are drasticaly inferior comparing to the the normal transaction which suggest an unbalanced repartition on the class. This situation can affect our model during its learning process"""
# Out:
# ' 1- By analysing the above table, we noticed the number of fraudulent transaction are drasticaly inferior comparing to the the normal transaction which suggest an unbalanced repartition on the class. This situation can affect our model during its learning process'

# %%
""" 2-The maximun amount of frandulant transaction in lower than the maximun amount of normal transaction. We conclue that a frandulant transaction is not necessarly a very High amount transaction """
# Out:
# ' 2-The maximun amount of frandulant transaction in lower than the maximun amount of normal transaction. We conclue that a frandulant transaction is not necessarly a very High amount transaction '

# %% [markdown]
# # 3- Data Visualization

# %%
#Defining the positions of the bars
x= np.arange(len(groupby_tab.keys()))

#Setting data
occurences_0=[]
occurences_1=[]
columns=groupby_tab.columns
for col in columns:
    occurences_0.append(groupby_tab[col][0])
    occurences_1.append(groupby_tab[col][1])

    
#Plot the bars
# for i in range(1,len(columns)):
#     plt.figure()
#     plt.bar(x[i],occurences_0[i],color='blue',label="Normal transaction")
#     plt.bar(x[i],occurences_1[i],bottom=occurences_0[i],color='orange',label="Fraudulent Transaction")
#     # plt.xticks(x[i],columns[i])
#     plt.xlabel(columns[i])
#     plt.ylabel("Values")
#     plt.legend()
#     plt.show()

# Calculate total occurrences for each column to compute percentages
total_occurrences = np.array(occurences_0) + np.array(occurences_1)
percentages_0 = (np.array(occurences_0) / total_occurrences) * 100
percentages_1 = (np.array(occurences_1) / total_occurrences) * 100

# Plot each column in separate figures
for i in range(1,len(columns)):
    fig, ax = plt.subplots(figsize=(5, 5))
    
    # Plot the bars
    bars_0 = ax.bar(0, occurences_0[i], color='blue', label='Normal transaction')
    bars_1 = ax.bar(0, occurences_1[i], bottom=occurences_0[i], color='orange', label='Fraudulent Transaction')

    # Add title and labels to the axes
    plt.title(f'Histogram of Occurrences for {columns[i]}')
    plt.xlabel(columns[i])
    plt.ylabel('Value')
    plt.xticks([])  # Remove x-ticks since we are showing only one column
    
    # Add a legend
    plt.legend()

    # Add percentage labels inside the bars
    ax.text(0, occurences_0[i] / 2, f'{percentages_0[i]:.1f}%', ha='center', va='center', color='white', fontsize=10)
    ax.text(0, occurences_0[i] + occurences_1[i] / 2, f'{percentages_1[i]:.1f}%', ha='center', va='center', color='black', fontsize=10)

    # Show the plot
    plt.show()
# Out:
# C:\Users\judical\AppData\Local\Temp\ipykernel_1316\3975507285.py:26: RuntimeWarning: invalid value encountered in divide
#   percentages_0 = (np.array(occurences_0) / total_occurrences) * 100
# C:\Users\judical\AppData\Local\Temp\ipykernel_1316\3975507285.py:27: RuntimeWarning: invalid value encountered in divide
#   percentages_1 = (np.array(occurences_1) / total_occurrences) * 100

# %% [markdown]
# # 4- Machine Learning

# %% [markdown]
# ### Since our dataset is highly unbalance we will perform couple of machine learning technicques in order to have a powerfull model able to detect fraud easy and accuratly

# %% [markdown]
# ### We will use the following ensemble models from imblearn.ensemble : `BalancedRandomForestClassifier` , `EasyEnsembleClassifier`

# %%
# !pip install imbalanced-learn

# %%
from imblearn.ensemble import EasyEnsembleClassifier
from imblearn.ensemble import BalancedRandomForestClassifier
from sklearn.metrics import classification_report,roc_auc_score,roc_curve,precision_recall_curve,auc
from sklearn.model_selection import train_test_split

# %% [markdown]
# ## a- Data preparation

# %%
x=df.iloc[:,:-1]
y=df.iloc[:,-1]

# %%
xtrain,xtest,ytrain,ytest=train_test_split(x,y,test_size=0.2)

# %% [markdown]
# ## b- Model setting up and evaluation

# %%
from sklearn.metrics import roc_curve, auc, precision_recall_curve, classification_report
from imblearn.ensemble import EasyEnsembleClassifier, BalancedRandomForestClassifier
import matplotlib.pyplot as plt

models = {
    "EasyEnsembleClassifier": EasyEnsembleClassifier(),
    "BalancedRandomForestClassifier": BalancedRandomForestClassifier(),
}

evaluations = []

for model_name, model in models.items():
    evals = {}
    model.fit(xtrain, ytrain)
    
    ypred = model.predict(xtest)
    ypred_proba = model.predict_proba(xtest)[:, 1]  # Use probability of the positive class
    
    # ROC Curve and AUC
    fpr, tpr, _ = roc_curve(ytest, ypred_proba)
    roc_auc = auc(fpr, tpr)
    
    plt.figure()
    plt.plot(fpr, tpr, color='darkorange', lw=2, label='ROC curve (area = %0.2f)' % roc_auc)
    plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
    plt.xlim([0.0, 1.0])
    plt.ylim([0.0, 1.05])
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.title(f'Receiver Operating Characteristic {model_name}')
    plt.legend(loc="lower right")
    plt.show()
    
    # Precision-Recall Curve and AUC
    precision, recall, _ = precision_recall_curve(ytest, ypred_proba)
    pr_auc = auc(recall, precision)
    
    evals["Precision"], evals["Recall"] = precision, recall
    evals["Precision Recall AUC"] = pr_auc
    
    plt.figure()
    plt.plot(recall, precision, color='blue', lw=2, label='Precision-Recall curve (area = %0.2f)' % pr_auc)
    plt.xlabel('Recall')
    plt.ylabel('Precision')
    plt.title(f'Precision-Recall Curve {model_name}')
    plt.legend(loc="lower left")
    plt.show()
    
    evaluations.append((model_name, evals))

for model_name, evals in evaluations:
    print(f"Model: {model_name}")
    print(f"Precision-Recall AUC: {evals['Precision Recall AUC']:.2f}")
    print(classification_report(ytest, models[model_name].predict(xtest)))
# Out:
# C:\Users\judical\anaconda3\lib\site-packages\imblearn\ensemble\_forest.py:546: FutureWarning: The default of `sampling_strategy` will change from `'auto'` to `'all'` in version 0.13. This change will follow the implementation proposed in the original paper. Set to `'all'` to silence this warning and adopt the future behaviour.
#   warn(
# C:\Users\judical\anaconda3\lib\site-packages\imblearn\ensemble\_forest.py:558: FutureWarning: The default of `replacement` will change from `False` to `True` in version 0.13. This change will follow the implementation proposed in the original paper. Set to `True` to silence this warning and adopt the future behaviour.
#   warn(
# Model: EasyEnsembleClassifier
# Precision-Recall AUC: 0.83
#               precision    recall  f1-score   support
#
#            0       1.00      0.97      0.98     56860
#            1       0.05      0.87      0.09       102
#
#     accuracy                           0.97     56962
# ...

# %% [markdown]
# ## c- Interpreation

# %% [markdown]
# Since our dataset is highly imbalanced the more informatives metrics are Precisions-Recall AUC.
#
# `Precision-Recall AUC`:  Both models (0.83-> EassyEnsembleClassifier , 0.82 -> BalancedRandomForestClassifier)  perform well in distinguishing between the classes,particularly in the minority class(positive class)

# %% [markdown]
# ## d-Saving the model

# %%
model=EasyEnsembleClassifier()
model.fit(xtrain, ytrain)
# Out:
# EasyEnsembleClassifier()

# %%
import joblib
#saving 
joblib.dump(model,"model.pkl")
# Out:
# ['model.pkl']

# %%
# !code .
